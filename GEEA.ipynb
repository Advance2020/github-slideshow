# %% [markdown]
# <a href="https://colab.research.google.com/github/Advance2020/github-slideshow/blob/main/GEEA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 连接google drive 便于上传数据集

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
# !git clone https://github.com/Dlut-lab-zmn/GEAA-for-data-protection.git
# Out:
# Cloning into 'GEAA-for-data-protection'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 133 (delta 4), reused 0 (delta 0), pack-reused 124
# Receiving objects: 100% (133/133), 77.83 KiB | 5.56 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
cd GEAA-for-data-protection/data/cifar_data/
# Out:
# /content/sample_data/GEAA-for-data-protection/data/cifar_data

# %% [markdown]
# 解压数据集，后面要记得改代码，按照要求目录文件进行重命名

# %%
# !unzip cifar_data.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: cifar10/train/truck/0001.png
#   inflating: cifar10/train/truck/0002.png
#   inflating: cifar10/train/truck/0003.png
#   inflating: cifar10/train/truck/0004.png
#   inflating: cifar10/train/truck/0005.png
#   inflating: cifar10/train/truck/0006.png
#   inflating: cifar10/train/truck/0007.png
#   inflating: cifar10/train/truck/0008.png
#   inflating: cifar10/train/truck/0009.png
#   inflating: cifar10/train/truck/0010.png
#   inflating: cifar10/train/truck/0011.png
#   inflating: cifar10/train/truck/0012.png
#   inflating: cifar10/train/truck/0013.png
#   inflating: cifar10/train/truck/0014.png
#   inflating: cifar10/train/truck/0015.png
#   inflating: cifar10/train/truck/0016.png
#   inflating: cifar10/train/truck/0017.png
#   inflating: cifar10/train/truck/0018.png
#   inflating: cifar10/train/truck/0019.png
#   inflating: cifar10/train/truck/0020.png
#   inflating: cifar10/train/truck/0021.png
#   inflating: cifar10/train/truck/0022.png
# ...

# %%
pwd
# Out:
# '/content/sample_data/GEAA-for-data-protection/data/cifar_data'

# %%
cd cifar_data
# Out:
# /content/sample_data/GEAA-for-data-protection/data/cifar_data

# %%
# !python generate_dirs.py

# %%
cp -r ./cifar_data/test/* ./adv/test

# %%
cp -r ./cifar_data/test/* ./process/test

# %% [markdown]
# 运行下面两次，回到GEAA目录下

# %%
import os
os.chdir("../")

# %%
pwd
# Out:
# '/content/sample_data/GEAA-for-data-protection'

# %% [markdown]
# 训练分类网络，200个epoch，耗时1.5h

# %%
# !python train_class_net.py --load_path './data/cifar_data/cifar_data' --dataset 'cifar' --device '0' --save_name 'cifar'
# Out:
# ==> Building model..
# load in!
# Train load down 50000
# Test load down 10000
# train_class_net.py:129: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   targets = torch.FloatTensor(targets)
#  [================================================================>]  Step: 21ms | Tot: 1s399ms | Loss: 0.230 | Acc: 9.900% (990/10000) 100/100
# Saving..
#
# Epoch: 0
#  [================================================================>]  Step: 90ms | Tot: 20s614ms | Loss: 0.145 | Acc: 46.863% (23394/49920) 390/390
#  [================================================================>]  Step: 21ms | Tot: 1s407ms | Loss: 0.133 | Acc: 54.510% (5451/10000) 100/100
# Saving..
#
# Epoch: 1
# ...

# %% [markdown]
# 将训练好的模型保存至Google drive

# %%
pwd
# Out:
# '/content/sample_data/GEAA-for-data-protection'

# %% [markdown]
# 运行报错，没有en_decoder库,修改注释

# %%
# !python train_en_decoder_finger.py --dataset 'cifar' --gama 0.9 --bound 10 --device '0'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Epoch: [1][240/250]	Loss 182.9059 (183.8506)	Prec@0 0.720	Prec@1 0.600	Prec@2 0.690	Prec@3 0.620
# input noise 12.079	noise_g1 29.973	noise_g2 26.498	max_g 166.222	insert_loss 0.329	rest_time 4.1 h
# 50.0
# Epoch: [2][0/250]	Loss 182.1304 (182.1304)	Prec@0 0.650	Prec@1 0.610	Prec@2 0.640	Prec@3 0.630
# input noise 11.378	noise_g1 28.018	noise_g2 25.123	max_g 187.661	insert_loss 0.321	rest_time 4.1 h
# 50.0
# Epoch: [2][40/250]	Loss 184.7691 (183.4497)	Prec@0 0.690	Prec@1 0.580	Prec@2 0.680	Prec@3 0.550
# input noise 14.117	noise_g1 30.002	noise_g2 29.337	max_g 173.741	insert_loss 0.337	rest_time 4.1 h
# 50.0
# Epoch: [2][80/250]	Loss 186.9939 (184.6311)	Prec@0 0.640	Prec@1 0.560	Prec@2 0.660	Prec@3 0.630
# input noise 13.022	noise_g1 29.723	noise_g2 29.435	max_g 204.886	insert_loss 0.329	rest_time 4.1 h
# 49.04132231404959
# Epoch: [2][120/250]	Loss 191.8873 (186.4452)	Prec@0 0.630	Prec@1 0.590	Prec@2 0.630	Prec@3 0.550
# ...
